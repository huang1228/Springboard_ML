# %% [markdown]
# ## Below are three examples of ASL images that will be used in the capstone project

# %%
from IPython.display import display, Image

# %%
image_file1 = '../Capstone project/Data/asl_alphabet_train/A/A100.jpg'

# %%
display(Image(filename=image_file1))

# %%
image_file2 = '../Capstone project/Data/asl_alphabet_train/del/del1007.jpg'

# %%
display(Image(filename=image_file2))

# %%
image_file3 = '../Capstone project/Data/asl_alphabet_train/nothing/nothing1032.jpg'

# %%
display(Image(filename=image_file3))
